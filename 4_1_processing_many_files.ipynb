# %%
import polars as pl
import polars.selectors as cs
from glob import glob

# %%
from composable.strict import map
from composable.object import obj

# %% [markdown]
# # Lecture 4.1 - Download and unzip files programmically.
#
# In this lecture, we will
#
# 1. Use `glob` to get local paths, and
# 2. Load multiple files using a list comprehension.
# 3. Combine multiple dataframes using `pd.concat`.
# 4. Add information from the path to the dataframe.

# %% [markdown]
# ## Loading multiple files using a list comprehension
#
# To load multiple files, we
# 1. Use `glob` to find the paths all relevant files.
# 2. Use a list comprehension to load the data into a list of DataFrames.
#
# The basic structure of this process is as follows.
#
# **Cell 1 - `glob` cell.**
# ```python
# from glob import glob
#
# (paths :=
#     glob("...glob_pattern using ** and *...", recursive=True)
# )
# ```
#
# **Cell 2 - List comprehension cell.**
# import polars as pl
#
# ```python
# (dfs :=
#   [pl.read_csv(p)
#    # Addition processing can go here as part of the dot-chained commands
#    for p in paths
#    # You can add an if statement here to filter files if needed
#  ]
# )
# ```

# %% [markdown]
# ### Example - Loading and combining all Attendance Quiz files and adding a path column
#
# Note that the `data/old_attendance_example` directory contains multiple CSV files which we want to load and combine.

# %% [markdown]
# #### Step 1 - Use `glob` to get all the paths
#
# **Cell 1 - `glob` cell.**
# ```python
# from glob import glob
#
# (paths :=
#     glob("...glob_pattern using ** and *...",
#          recursive=True                       # This allows ** to search any number of subdirectories
#          )
# )
# ```
#
# **Note.** See creation of `all_csvs` above

# %%
(all_csvs :=
 glob('./data/old_attendance_example/**/*.csv', 
      recursive=True # Toggle comment and see what happens
     )
)
# Out:
# ['./data/old_attendance_example\\dsci494s7\\Attendance Quiz - User Attempts.csv',
#  './data/old_attendance_example\\dsci494s7\\Practice Quiz - Module 1 - User Attempts.csv',
#  './data/old_attendance_example\\dsci494s7\\Practice Quiz - Module 2 - User Attempts.csv',
#  './data/old_attendance_example\\dsci494s7\\Practice Quiz - Module 3 - User Attempts.csv',
#  './data/old_attendance_example\\dsci494s7\\Practice Quiz - Module 4 - User Attempts.csv',
#  './data/old_attendance_example\\stat180s18\\Attendance Quiz - User Attempts.csv',
#  './data/old_attendance_example\\stat491s1\\Attendance Quiz - User Attempts.csv',
#  './data/old_attendance_example\\stat491s1\\Practice Quiz - Module 1 - User Attempts.csv',
#  './data/old_attendance_example\\stat491s1\\Practice Quiz - Module 2 - User Attempts.csv',
#  './data/old_attendance_example\\stat491s1\\Practice Quiz - Module 3 - User Attempts.csv',
#  './data/old_attendance_example\\stat491s1\\Practice Quiz - Module 4 - User Attempts.csv']

# %% [markdown]
# #### Step 2 - Use a comprehension to load each file and add a path column and combine with `pl.concat`
#
# **Cell 2 - List comprehension cell.**
# import polars as pl
#
# ```python
# (dfs :=
#   [pl.read_csv(p)
#    # Addition processing can go here as part of the dot-chained commands
#    for p in paths
#    # You can add an if statement here to filter files if needed
#  ]
# )
# ```
#
# **Note.** This requires all columns to have the same name and type across all files and that those columns are in the same order.

# %% [markdown]
# #### Step 2 - Read each CSV and add the path

# %%
(all_tables :=
    [pl.read_csv(p)
       .with_columns(path = pl.lit(p))
     for p in all_csvs
     if 'Attendance Quiz' in p
    ]
) >> map(obj.head(2))
# Out:
# [shape: (2, 11)
#  ┌────────────┬──────────┬───────────┬──────────┬───┬────────────┬────────────┬─────────┬───────────┐
#  │ Org        ┆ UserName ┆ FirstName ┆ LastName ┆ … ┆ Attempt_St ┆ Attempt_En ┆ Percent ┆ path      │
#  │ Defined ID ┆ ---      ┆ ---       ┆ ---      ┆   ┆ art        ┆ d          ┆ ---     ┆ ---       │
#  │ ---        ┆ str      ┆ str       ┆ str      ┆   ┆ ---        ┆ ---        ┆ str     ┆ str       │
#  │ i64        ┆          ┆           ┆          ┆   ┆ str        ┆ str        ┆         ┆           │
#  ╞════════════╪══════════╪═══════════╪══════════╪═══╪════════════╪════════════╪═════════╪═══════════╡
#  │ 14460432   ┆ au9747cp ┆ Jericho   ┆ Greer    ┆ … ┆ 2019-01-14 ┆ 2019-01-14 ┆ 100 %   ┆ ./data/ol │
#  │            ┆          ┆           ┆          ┆   ┆ 14:00:00   ┆ 14:06:00   ┆         ┆ d_attenda │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\dsci49 │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 4s7\Atten │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ dance     │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Quiz -    │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ User Atte │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ mpts.csv  │
#  │ 14460432   ┆ au9747cp ┆ Jericho   ┆ Greer    ┆ … ┆ 2019-01-16 ┆ 2019-01-16 ┆ 100 %   ┆ ./data/ol │
#  │            ┆          ┆           ┆          ┆   ┆ 14:00:00   ┆ 14:08:00   ┆         ┆ d_attenda │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\dsci49 │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 4s7\Atten │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ dance     │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Quiz -    │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ User Atte │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ mpts.csv  │
#  └────────────┴──────────┴───────────┴──────────┴───┴────────────┴────────────┴─────────┴───────────┘,
#  shape: (2, 11)
#  ┌────────────┬──────────┬───────────┬──────────┬───┬────────────┬────────────┬─────────┬───────────┐
#  │ Org        ┆ UserName ┆ FirstName ┆ LastName ┆ … ┆ Attempt_St ┆ Attempt_En ┆ Percent ┆ path      │
#  │ Defined ID ┆ ---      ┆ ---       ┆ ---      ┆   ┆ art        ┆ d          ┆ ---     ┆ ---       │
#  │ ---        ┆ str      ┆ str       ┆ str      ┆   ┆ ---        ┆ ---        ┆ str     ┆ str       │
#  │ i64        ┆          ┆           ┆          ┆   ┆ str        ┆ str        ┆         ┆           │
#  ╞════════════╪══════════╪═══════════╪══════════╪═══╪════════════╪════════════╪═════════╪═══════════╡
#  │ 14105436   ┆ uc4365aw ┆ Orville   ┆ Nyquist  ┆ … ┆ 2019-02-27 ┆ 2019-02-27 ┆ 100 %   ┆ ./data/ol │
#  │            ┆          ┆           ┆          ┆   ┆ 15:02:00   ┆ 15:10:00   ┆         ┆ d_attenda │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\stat18 │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 0s18\Atte │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ ndance    │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Quiz -    │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ User Atte │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ mpts.csv  │
#  │ 14105436   ┆ uc4365aw ┆ Orville   ┆ Nyquist  ┆ … ┆ 2019-03-04 ┆ 2019-03-04 ┆ 100 %   ┆ ./data/ol │
#  │            ┆          ┆           ┆          ┆   ┆ 15:07:00   ┆ 15:13:00   ┆         ┆ d_attenda │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\stat18 │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 0s18\Atte │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ ndance    │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Quiz -    │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ User Atte │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ mpts.csv  │
#  └────────────┴──────────┴───────────┴──────────┴───┴────────────┴────────────┴─────────┴───────────┘,
#  shape: (2, 11)
#  ┌────────────┬──────────┬───────────┬──────────┬───┬────────────┬────────────┬─────────┬───────────┐
#  │ Org        ┆ UserName ┆ FirstName ┆ LastName ┆ … ┆ Attempt_St ┆ Attempt_En ┆ Percent ┆ path      │
#  │ Defined ID ┆ ---      ┆ ---       ┆ ---      ┆   ┆ art        ┆ d          ┆ ---     ┆ ---       │
#  │ ---        ┆ str      ┆ str       ┆ str      ┆   ┆ ---        ┆ ---        ┆ str     ┆ str       │
#  │ i64        ┆          ┆           ┆          ┆   ┆ str        ┆ str        ┆         ┆           │
#  ╞════════════╪══════════╪═══════════╪══════════╪═══╪════════════╪════════════╪═════════╪═══════════╡
#  │ 15135961   ┆ wd8670of ┆ McKinley  ┆ Sabina   ┆ … ┆ 2019-02-05 ┆ 2019-02-05 ┆ 100 %   ┆ ./data/ol │
#  │            ┆          ┆           ┆          ┆   ┆ 09:07:00   ┆ 09:11:00   ┆         ┆ d_attenda │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\stat49 │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 1s1\Atten │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ dance     │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Quiz -    │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ User Atte │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ mpts.csv  │
#  │ 15135961   ┆ wd8670of ┆ McKinley  ┆ Sabina   ┆ … ┆ 2019-02-07 ┆ 2019-02-07 ┆ 100 %   ┆ ./data/ol │
#  │            ┆          ┆           ┆          ┆   ┆ 09:01:00   ┆ 09:07:00   ┆         ┆ d_attenda │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\stat49 │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 1s1\Atten │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ dance     │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Quiz -    │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ User Atte │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ mpts.csv  │
#  └────────────┴──────────┴───────────┴──────────┴───┴────────────┴────────────┴─────────┴───────────┘]

# %% [markdown]
# #### Step 3 - Union the tables - YOLO!!!!
#
# Taking a chance that
# 1. All the columns are the same (type, name, etc.), and
# 2. The columns are in the same order.

# %%
(attendance_quizzes :=
 pl.concat(all_tables)
).head()
# Out:
# shape: (5, 11)
# ┌────────────┬──────────┬───────────┬──────────┬───┬────────────┬────────────┬─────────┬───────────┐
# │ Org        ┆ UserName ┆ FirstName ┆ LastName ┆ … ┆ Attempt_St ┆ Attempt_En ┆ Percent ┆ path      │
# │ Defined ID ┆ ---      ┆ ---       ┆ ---      ┆   ┆ art        ┆ d          ┆ ---     ┆ ---       │
# │ ---        ┆ str      ┆ str       ┆ str      ┆   ┆ ---        ┆ ---        ┆ str     ┆ str       │
# │ i64        ┆          ┆           ┆          ┆   ┆ str        ┆ str        ┆         ┆           │
# ╞════════════╪══════════╪═══════════╪══════════╪═══╪════════════╪════════════╪═════════╪═══════════╡
# │ 14460432   ┆ au9747cp ┆ Jericho   ┆ Greer    ┆ … ┆ 2019-01-14 ┆ 2019-01-14 ┆ 100 %   ┆ ./data/ol │
# │            ┆          ┆           ┆          ┆   ┆ 14:00:00   ┆ 14:06:00   ┆         ┆ d_attenda │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\dsci49 │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 4s7\Atten │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ dance     │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Quiz -    │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ User Atte │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ mpts.csv  │
# │ 14460432   ┆ au9747cp ┆ Jericho   ┆ Greer    ┆ … ┆ 2019-01-16 ┆ 2019-01-16 ┆ 100 %   ┆ ./data/ol │
# │            ┆          ┆           ┆          ┆   ┆ 14:00:00   ┆ 14:08:00   ┆         ┆ d_attenda │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\dsci49 │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 4s7\Atten │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ dance     │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Quiz -    │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ User Atte │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ mpts.csv  │
# │ 14460432   ┆ au9747cp ┆ Jericho   ┆ Greer    ┆ … ┆ 2019-01-18 ┆ 2019-01-18 ┆ 100 %   ┆ ./data/ol │
# │            ┆          ┆           ┆          ┆   ┆ 14:00:00   ┆ 14:05:00   ┆         ┆ d_attenda │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\dsci49 │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 4s7\Atten │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ dance     │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Quiz -    │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ User Atte │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ mpts.csv  │
# │ 14460432   ┆ au9747cp ┆ Jericho   ┆ Greer    ┆ … ┆ 2019-01-23 ┆ 2019-01-23 ┆ 100 %   ┆ ./data/ol │
# │            ┆          ┆           ┆          ┆   ┆ 14:00:00   ┆ 14:06:00   ┆         ┆ d_attenda │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\dsci49 │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 4s7\Atten │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ dance     │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Quiz -    │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ User Atte │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ mpts.csv  │
# │ 14460432   ┆ au9747cp ┆ Jericho   ┆ Greer    ┆ … ┆ 2019-01-25 ┆ 2019-01-25 ┆ 100 %   ┆ ./data/ol │
# │            ┆          ┆           ┆          ┆   ┆ 14:00:00   ┆ 14:10:00   ┆         ┆ d_attenda │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\dsci49 │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 4s7\Atten │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ dance     │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Quiz -    │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ User Atte │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ mpts.csv  │
# └────────────┴──────────┴───────────┴──────────┴───┴────────────┴────────────┴─────────┴───────────┘

# %% [markdown]
# ### Step 4 - Extract information from the path
#
# Finally, we will use `polars` string methods to extract the course information from the path.

# %%
pl.Config.set_fmt_table_cell_list_len(200) # Make the list column output longer
pl.Config.set_fmt_str_lengths(200) # Make string column output longer

(attendance_quizzes_w_info :=
 attendance_quizzes

.with_columns(path=pl.col('path').str.replace_all(r'\\', '/'))  # Replace \ with /
    .with_columns(path_split=pl.col('path').str.split('/'))
.with_columns(course_info = pl.col('path_split').list.get(3),
               file_name = pl.col('path_split').list.get(-1),
              )
  .with_columns(program = pl.col('course_info').str.slice(0,4),
                course_number = pl.col('course_info').str.slice(4, 3),
                section = pl.col('course_info').str.slice(7),
                quiz_type = pl.col('file_name').str.split(' ').list.get(0),
                )
 .drop(cs.starts_with('path', 'file') | cs.ends_with('info'))

)
# Out:
# shape: (1_748, 14)
# ┌─────────────┬──────────┬───────────┬──────────┬───┬─────────┬─────────────┬─────────┬────────────┐
# │ Org Defined ┆ UserName ┆ FirstName ┆ LastName ┆ … ┆ program ┆ course_numb ┆ section ┆ quiz_type  │
# │ ID          ┆ ---      ┆ ---       ┆ ---      ┆   ┆ ---     ┆ er          ┆ ---     ┆ ---        │
# │ ---         ┆ str      ┆ str       ┆ str      ┆   ┆ str     ┆ ---         ┆ str     ┆ str        │
# │ i64         ┆          ┆           ┆          ┆   ┆         ┆ str         ┆         ┆            │
# ╞═════════════╪══════════╪═══════════╪══════════╪═══╪═════════╪═════════════╪═════════╪════════════╡
# │ 14460432    ┆ au9747cp ┆ Jericho   ┆ Greer    ┆ … ┆ dsci    ┆ 494         ┆ s7      ┆ Attendance │
# │ 14460432    ┆ au9747cp ┆ Jericho   ┆ Greer    ┆ … ┆ dsci    ┆ 494         ┆ s7      ┆ Attendance │
# │ 14460432    ┆ au9747cp ┆ Jericho   ┆ Greer    ┆ … ┆ dsci    ┆ 494         ┆ s7      ┆ Attendance │
# │ 14460432    ┆ au9747cp ┆ Jericho   ┆ Greer    ┆ … ┆ dsci    ┆ 494         ┆ s7      ┆ Attendance │
# │ 14460432    ┆ au9747cp ┆ Jericho   ┆ Greer    ┆ … ┆ dsci    ┆ 494         ┆ s7      ┆ Attendance │
# │ …           ┆ …        ┆ …         ┆ …        ┆ … ┆ …       ┆ …           ┆ …       ┆ …          │
# │ 12630683    ┆ iv8164nd ┆ Vinci     ┆ Alberich ┆ … ┆ stat    ┆ 491         ┆ s1      ┆ Attendance │
# │ 12630683    ┆ iv8164nd ┆ Vinci     ┆ Alberich ┆ … ┆ stat    ┆ 491         ┆ s1      ┆ Attendance │
# │ 12630683    ┆ iv8164nd ┆ Vinci     ┆ Alberich ┆ … ┆ stat    ┆ 491         ┆ s1      ┆ Attendance │
# │ 12630683    ┆ iv8164nd ┆ Vinci     ┆ Alberich ┆ … ┆ stat    ┆ 491         ┆ s1      ┆ Attendance │
# │ 12630683    ┆ iv8164nd ┆ Vinci     ┆ Alberich ┆ … ┆ stat    ┆ 491         ┆ s1      ┆ Attendance │
# └─────────────┴──────────┴───────────┴──────────┴───┴─────────┴─────────────┴─────────┴────────────┘

# %% [markdown]
# ## <font color="red"> Exercise 3.1.2 - Combine all `Practice Quizzes` files</font>
#
# Now you try it. Combine all the `Practice Quiz` files in the `data/old_attendance_example` directory. Add a column with the path to each dataframe before combining them.
#
# 1. Use `glob` to get all the paths to the CSV files.
# 2. Use a list comprehension to read each CSV file, filter for `Practice Quiz` files, and add a column with the path.
# 3. Combine all the dataframes using `pl.concat`.
# 4. Extract the course information from the path and add it as a column.

# %%
# Your code here
(all_csvA :=
 glob('./data/old_attendance_example/**/*.csv', 
      recursive=True # Toggle comment and see what happens
     )
)
# Out:
# ['./data/old_attendance_example\\dsci494s7\\Attendance Quiz - User Attempts.csv',
#  './data/old_attendance_example\\dsci494s7\\Practice Quiz - Module 1 - User Attempts.csv',
#  './data/old_attendance_example\\dsci494s7\\Practice Quiz - Module 2 - User Attempts.csv',
#  './data/old_attendance_example\\dsci494s7\\Practice Quiz - Module 3 - User Attempts.csv',
#  './data/old_attendance_example\\dsci494s7\\Practice Quiz - Module 4 - User Attempts.csv',
#  './data/old_attendance_example\\stat180s18\\Attendance Quiz - User Attempts.csv',
#  './data/old_attendance_example\\stat491s1\\Attendance Quiz - User Attempts.csv',
#  './data/old_attendance_example\\stat491s1\\Practice Quiz - Module 1 - User Attempts.csv',
#  './data/old_attendance_example\\stat491s1\\Practice Quiz - Module 2 - User Attempts.csv',
#  './data/old_attendance_example\\stat491s1\\Practice Quiz - Module 3 - User Attempts.csv',
#  './data/old_attendance_example\\stat491s1\\Practice Quiz - Module 4 - User Attempts.csv']

# %%
(all_tables :=
    [pl.read_csv(P)
       .with_columns(path = pl.lit(P))
     for P in all_csvs
     if 'Practice Quiz' in P
    ]
) >> map(obj.head(2))
# Out:
# [shape: (2, 11)
#  ┌────────────┬──────────┬───────────┬──────────┬───┬────────────┬────────────┬─────────┬───────────┐
#  │ Org        ┆ UserName ┆ FirstName ┆ LastName ┆ … ┆ Attempt_St ┆ Attempt_En ┆ Percent ┆ path      │
#  │ Defined ID ┆ ---      ┆ ---       ┆ ---      ┆   ┆ art        ┆ d          ┆ ---     ┆ ---       │
#  │ ---        ┆ str      ┆ str       ┆ str      ┆   ┆ ---        ┆ ---        ┆ str     ┆ str       │
#  │ i64        ┆          ┆           ┆          ┆   ┆ str        ┆ str        ┆         ┆           │
#  ╞════════════╪══════════╪═══════════╪══════════╪═══╪════════════╪════════════╪═════════╪═══════════╡
#  │ 14460432   ┆ au9747cp ┆ Jericho   ┆ Greer    ┆ … ┆ 2019-01-28 ┆ 2019-01-28 ┆ 50 %    ┆ ./data/ol │
#  │            ┆          ┆           ┆          ┆   ┆ 15:26:00   ┆ 15:30:00   ┆         ┆ d_attenda │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\dsci49 │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 4s7\Pract │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ ice Quiz  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ - Module  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 1 - User  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Attempts. │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ csv       │
#  │ 14460432   ┆ au9747cp ┆ Jericho   ┆ Greer    ┆ … ┆ 2019-01-27 ┆ 2019-01-27 ┆ 95 %    ┆ ./data/ol │
#  │            ┆          ┆           ┆          ┆   ┆ 15:25:00   ┆ 15:34:00   ┆         ┆ d_attenda │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\dsci49 │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 4s7\Pract │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ ice Quiz  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ - Module  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 1 - User  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Attempts. │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ csv       │
#  └────────────┴──────────┴───────────┴──────────┴───┴────────────┴────────────┴─────────┴───────────┘,
#  shape: (2, 11)
#  ┌────────────┬──────────┬───────────┬──────────┬───┬────────────┬────────────┬─────────┬───────────┐
#  │ Org        ┆ UserName ┆ FirstName ┆ LastName ┆ … ┆ Attempt_St ┆ Attempt_En ┆ Percent ┆ path      │
#  │ Defined ID ┆ ---      ┆ ---       ┆ ---      ┆   ┆ art        ┆ d          ┆ ---     ┆ ---       │
#  │ ---        ┆ str      ┆ str       ┆ str      ┆   ┆ ---        ┆ ---        ┆ str     ┆ str       │
#  │ i64        ┆          ┆           ┆          ┆   ┆ str        ┆ str        ┆         ┆           │
#  ╞════════════╪══════════╪═══════════╪══════════╪═══╪════════════╪════════════╪═════════╪═══════════╡
#  │ 14460432   ┆ au9747cp ┆ Jericho   ┆ Greer    ┆ … ┆ 2019-02-01 ┆ 2019-02-01 ┆ 45 %    ┆ ./data/ol │
#  │            ┆          ┆           ┆          ┆   ┆ 15:43:00   ┆ 15:47:00   ┆         ┆ d_attenda │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\dsci49 │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 4s7\Pract │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ ice Quiz  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ - Module  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 2 - User  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Attempts. │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ csv       │
#  │ 14460432   ┆ au9747cp ┆ Jericho   ┆ Greer    ┆ … ┆ 2019-02-03 ┆ 2019-02-03 ┆ 95 %    ┆ ./data/ol │
#  │            ┆          ┆           ┆          ┆   ┆ 15:02:00   ┆ 15:10:00   ┆         ┆ d_attenda │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\dsci49 │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 4s7\Pract │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ ice Quiz  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ - Module  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 2 - User  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Attempts. │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ csv       │
#  └────────────┴──────────┴───────────┴──────────┴───┴────────────┴────────────┴─────────┴───────────┘,
#  shape: (2, 11)
#  ┌────────────┬──────────┬───────────┬──────────┬───┬────────────┬────────────┬─────────┬───────────┐
#  │ Org        ┆ UserName ┆ FirstName ┆ LastName ┆ … ┆ Attempt_St ┆ Attempt_En ┆ Percent ┆ path      │
#  │ Defined ID ┆ ---      ┆ ---       ┆ ---      ┆   ┆ art        ┆ d          ┆ ---     ┆ ---       │
#  │ ---        ┆ str      ┆ str       ┆ str      ┆   ┆ ---        ┆ ---        ┆ str     ┆ str       │
#  │ i64        ┆          ┆           ┆          ┆   ┆ str        ┆ str        ┆         ┆           │
#  ╞════════════╪══════════╪═══════════╪══════════╪═══╪════════════╪════════════╪═════════╪═══════════╡
#  │ 14460432   ┆ au9747cp ┆ Jericho   ┆ Greer    ┆ … ┆ 2019-02-10 ┆ 2019-02-10 ┆ 55 %    ┆ ./data/ol │
#  │            ┆          ┆           ┆          ┆   ┆ 15:44:00   ┆ 15:52:00   ┆         ┆ d_attenda │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\dsci49 │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 4s7\Pract │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ ice Quiz  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ - Module  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 3 - User  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Attempts. │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ csv       │
#  │ 14460432   ┆ au9747cp ┆ Jericho   ┆ Greer    ┆ … ┆ 2019-02-11 ┆ 2019-02-11 ┆ 15 %    ┆ ./data/ol │
#  │            ┆          ┆           ┆          ┆   ┆ 15:16:00   ┆ 15:24:00   ┆         ┆ d_attenda │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\dsci49 │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 4s7\Pract │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ ice Quiz  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ - Module  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 3 - User  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Attempts. │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ csv       │
#  └────────────┴──────────┴───────────┴──────────┴───┴────────────┴────────────┴─────────┴───────────┘,
#  shape: (2, 11)
#  ┌────────────┬──────────┬───────────┬──────────┬───┬────────────┬────────────┬─────────┬───────────┐
#  │ Org        ┆ UserName ┆ FirstName ┆ LastName ┆ … ┆ Attempt_St ┆ Attempt_En ┆ Percent ┆ path      │
#  │ Defined ID ┆ ---      ┆ ---       ┆ ---      ┆   ┆ art        ┆ d          ┆ ---     ┆ ---       │
#  │ ---        ┆ str      ┆ str       ┆ str      ┆   ┆ ---        ┆ ---        ┆ str     ┆ str       │
#  │ i64        ┆          ┆           ┆          ┆   ┆ str        ┆ str        ┆         ┆           │
#  ╞════════════╪══════════╪═══════════╪══════════╪═══╪════════════╪════════════╪═════════╪═══════════╡
#  │ 14460432   ┆ au9747cp ┆ Jericho   ┆ Greer    ┆ … ┆ 2019-02-24 ┆ 2019-02-24 ┆ 25 %    ┆ ./data/ol │
#  │            ┆          ┆           ┆          ┆   ┆ 15:37:00   ┆ 15:39:00   ┆         ┆ d_attenda │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\dsci49 │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 4s7\Pract │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ ice Quiz  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ - Module  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 4 - User  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Attempts. │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ csv       │
#  │ 14460432   ┆ au9747cp ┆ Jericho   ┆ Greer    ┆ … ┆ 2019-02-24 ┆ 2019-02-24 ┆ 25 %    ┆ ./data/ol │
#  │            ┆          ┆           ┆          ┆   ┆ 15:42:00   ┆ 15:47:00   ┆         ┆ d_attenda │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\dsci49 │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 4s7\Pract │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ ice Quiz  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ - Module  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 4 - User  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Attempts. │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ csv       │
#  └────────────┴──────────┴───────────┴──────────┴───┴────────────┴────────────┴─────────┴───────────┘,
#  shape: (2, 11)
#  ┌────────────┬──────────┬───────────┬──────────┬───┬────────────┬────────────┬─────────┬───────────┐
#  │ Org        ┆ UserName ┆ FirstName ┆ LastName ┆ … ┆ Attempt_St ┆ Attempt_En ┆ Percent ┆ path      │
#  │ Defined ID ┆ ---      ┆ ---       ┆ ---      ┆   ┆ art        ┆ d          ┆ ---     ┆ ---       │
#  │ ---        ┆ str      ┆ str       ┆ str      ┆   ┆ ---        ┆ ---        ┆ str     ┆ str       │
#  │ i64        ┆          ┆           ┆          ┆   ┆ str        ┆ str        ┆         ┆           │
#  ╞════════════╪══════════╪═══════════╪══════════╪═══╪════════════╪════════════╪═════════╪═══════════╡
#  │ 15135961   ┆ wd8670of ┆ McKinley  ┆ Sabina   ┆ … ┆ 2019-01-28 ┆ 2019-01-28 ┆ 25 %    ┆ ./data/ol │
#  │            ┆          ┆           ┆          ┆   ┆ 15:40:00   ┆ 15:48:00   ┆         ┆ d_attenda │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\stat49 │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 1s1\Pract │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ ice Quiz  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ - Module  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 1 - User  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Attempts. │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ csv       │
#  │ 15135961   ┆ wd8670of ┆ McKinley  ┆ Sabina   ┆ … ┆ 2019-01-28 ┆ 2019-01-28 ┆ 60 %    ┆ ./data/ol │
#  │            ┆          ┆           ┆          ┆   ┆ 15:49:00   ┆ 15:56:00   ┆         ┆ d_attenda │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\stat49 │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 1s1\Pract │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ ice Quiz  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ - Module  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 1 - User  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Attempts. │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ csv       │
#  └────────────┴──────────┴───────────┴──────────┴───┴────────────┴────────────┴─────────┴───────────┘,
#  shape: (2, 11)
#  ┌────────────┬──────────┬───────────┬──────────┬───┬────────────┬────────────┬─────────┬───────────┐
#  │ Org        ┆ UserName ┆ FirstName ┆ LastName ┆ … ┆ Attempt_St ┆ Attempt_En ┆ Percent ┆ path      │
#  │ Defined ID ┆ ---      ┆ ---       ┆ ---      ┆   ┆ art        ┆ d          ┆ ---     ┆ ---       │
#  │ ---        ┆ str      ┆ str       ┆ str      ┆   ┆ ---        ┆ ---        ┆ str     ┆ str       │
#  │ i64        ┆          ┆           ┆          ┆   ┆ str        ┆ str        ┆         ┆           │
#  ╞════════════╪══════════╪═══════════╪══════════╪═══╪════════════╪════════════╪═════════╪═══════════╡
#  │ 15135961   ┆ wd8670of ┆ McKinley  ┆ Sabina   ┆ … ┆ 2019-02-03 ┆ 2019-02-03 ┆ 70 %    ┆ ./data/ol │
#  │            ┆          ┆           ┆          ┆   ┆ 15:47:00   ┆ 15:49:00   ┆         ┆ d_attenda │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\stat49 │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 1s1\Pract │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ ice Quiz  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ - Module  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 2 - User  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Attempts. │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ csv       │
#  │ 15135961   ┆ wd8670of ┆ McKinley  ┆ Sabina   ┆ … ┆ 2019-02-28 ┆ 2019-02-28 ┆ 20 %    ┆ ./data/ol │
#  │            ┆          ┆           ┆          ┆   ┆ 15:01:00   ┆ 15:02:00   ┆         ┆ d_attenda │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\stat49 │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 1s1\Pract │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ ice Quiz  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ - Module  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 2 - User  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Attempts. │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ csv       │
#  └────────────┴──────────┴───────────┴──────────┴───┴────────────┴────────────┴─────────┴───────────┘,
#  shape: (2, 11)
#  ┌────────────┬──────────┬───────────┬──────────┬───┬────────────┬────────────┬─────────┬───────────┐
#  │ Org        ┆ UserName ┆ FirstName ┆ LastName ┆ … ┆ Attempt_St ┆ Attempt_En ┆ Percent ┆ path      │
#  │ Defined ID ┆ ---      ┆ ---       ┆ ---      ┆   ┆ art        ┆ d          ┆ ---     ┆ ---       │
#  │ ---        ┆ str      ┆ str       ┆ str      ┆   ┆ ---        ┆ ---        ┆ str     ┆ str       │
#  │ i64        ┆          ┆           ┆          ┆   ┆ str        ┆ str        ┆         ┆           │
#  ╞════════════╪══════════╪═══════════╪══════════╪═══╪════════════╪════════════╪═════════╪═══════════╡
#  │ 15135961   ┆ wd8670of ┆ McKinley  ┆ Sabina   ┆ … ┆ 2019-02-09 ┆ 2019-02-09 ┆ 5 %     ┆ ./data/ol │
#  │            ┆          ┆           ┆          ┆   ┆ 11:33:00   ┆ 11:35:00   ┆         ┆ d_attenda │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\stat49 │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 1s1\Pract │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ ice Quiz  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ - Module  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 3 - User  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Attempts. │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ csv       │
#  │ 15135961   ┆ wd8670of ┆ McKinley  ┆ Sabina   ┆ … ┆ 2019-02-09 ┆ 2019-02-09 ┆ 100 %   ┆ ./data/ol │
#  │            ┆          ┆           ┆          ┆   ┆ 11:34:00   ┆ 11:40:00   ┆         ┆ d_attenda │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\stat49 │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 1s1\Pract │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ ice Quiz  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ - Module  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 3 - User  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Attempts. │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ csv       │
#  └────────────┴──────────┴───────────┴──────────┴───┴────────────┴────────────┴─────────┴───────────┘,
#  shape: (2, 11)
#  ┌────────────┬──────────┬───────────┬──────────┬───┬────────────┬────────────┬─────────┬───────────┐
#  │ Org        ┆ UserName ┆ FirstName ┆ LastName ┆ … ┆ Attempt_St ┆ Attempt_En ┆ Percent ┆ path      │
#  │ Defined ID ┆ ---      ┆ ---       ┆ ---      ┆   ┆ art        ┆ d          ┆ ---     ┆ ---       │
#  │ ---        ┆ str      ┆ str       ┆ str      ┆   ┆ ---        ┆ ---        ┆ str     ┆ str       │
#  │ i64        ┆          ┆           ┆          ┆   ┆ str        ┆ str        ┆         ┆           │
#  ╞════════════╪══════════╪═══════════╪══════════╪═══╪════════════╪════════════╪═════════╪═══════════╡
#  │ 15135961   ┆ wd8670of ┆ McKinley  ┆ Sabina   ┆ … ┆ 2019-02-24 ┆ 2019-02-24 ┆ 45 %    ┆ ./data/ol │
#  │            ┆          ┆           ┆          ┆   ┆ 11:01:00   ┆ 11:04:00   ┆         ┆ d_attenda │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\stat49 │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 1s1\Pract │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ ice Quiz  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ - Module  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 4 - User  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Attempts. │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ csv       │
#  │ 15135961   ┆ wd8670of ┆ McKinley  ┆ Sabina   ┆ … ┆ 2019-02-25 ┆ 2019-02-25 ┆ 65 %    ┆ ./data/ol │
#  │            ┆          ┆           ┆          ┆   ┆ 11:59:00   ┆ 12:06:00   ┆         ┆ d_attenda │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\stat49 │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 1s1\Pract │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ ice Quiz  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ - Module  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 4 - User  │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Attempts. │
#  │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ csv       │
#  └────────────┴──────────┴───────────┴──────────┴───┴────────────┴────────────┴─────────┴───────────┘]

# %%
(practice_quizzes :=
 pl.concat(all_tables)
).head()
# Out:
# shape: (5, 11)
# ┌────────────┬──────────┬───────────┬──────────┬───┬────────────┬────────────┬─────────┬───────────┐
# │ Org        ┆ UserName ┆ FirstName ┆ LastName ┆ … ┆ Attempt_St ┆ Attempt_En ┆ Percent ┆ path      │
# │ Defined ID ┆ ---      ┆ ---       ┆ ---      ┆   ┆ art        ┆ d          ┆ ---     ┆ ---       │
# │ ---        ┆ str      ┆ str       ┆ str      ┆   ┆ ---        ┆ ---        ┆ str     ┆ str       │
# │ i64        ┆          ┆           ┆          ┆   ┆ str        ┆ str        ┆         ┆           │
# ╞════════════╪══════════╪═══════════╪══════════╪═══╪════════════╪════════════╪═════════╪═══════════╡
# │ 14460432   ┆ au9747cp ┆ Jericho   ┆ Greer    ┆ … ┆ 2019-01-28 ┆ 2019-01-28 ┆ 50 %    ┆ ./data/ol │
# │            ┆          ┆           ┆          ┆   ┆ 15:26:00   ┆ 15:30:00   ┆         ┆ d_attenda │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\dsci49 │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 4s7\Pract │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ ice Quiz  │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ - Module  │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 1 - User  │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Attempts. │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ csv       │
# │ 14460432   ┆ au9747cp ┆ Jericho   ┆ Greer    ┆ … ┆ 2019-01-27 ┆ 2019-01-27 ┆ 95 %    ┆ ./data/ol │
# │            ┆          ┆           ┆          ┆   ┆ 15:25:00   ┆ 15:34:00   ┆         ┆ d_attenda │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\dsci49 │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 4s7\Pract │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ ice Quiz  │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ - Module  │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 1 - User  │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Attempts. │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ csv       │
# │ 14460432   ┆ au9747cp ┆ Jericho   ┆ Greer    ┆ … ┆ 2019-01-27 ┆ 2019-01-27 ┆ 55 %    ┆ ./data/ol │
# │            ┆          ┆           ┆          ┆   ┆ 15:29:00   ┆ 15:33:00   ┆         ┆ d_attenda │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\dsci49 │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 4s7\Pract │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ ice Quiz  │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ - Module  │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 1 - User  │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Attempts. │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ csv       │
# │ 14460432   ┆ au9747cp ┆ Jericho   ┆ Greer    ┆ … ┆ 2019-01-27 ┆ 2019-01-27 ┆ 45 %    ┆ ./data/ol │
# │            ┆          ┆           ┆          ┆   ┆ 15:37:00   ┆ 15:38:00   ┆         ┆ d_attenda │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\dsci49 │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 4s7\Pract │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ ice Quiz  │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ - Module  │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 1 - User  │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Attempts. │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ csv       │
# │ 14460432   ┆ au9747cp ┆ Jericho   ┆ Greer    ┆ … ┆ 2019-01-27 ┆ 2019-01-27 ┆ 15 %    ┆ ./data/ol │
# │            ┆          ┆           ┆          ┆   ┆ 15:43:00   ┆ 15:49:00   ┆         ┆ d_attenda │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ nce_examp │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ le\dsci49 │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 4s7\Pract │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ ice Quiz  │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ - Module  │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ 1 - User  │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ Attempts. │
# │            ┆          ┆           ┆          ┆   ┆            ┆            ┆         ┆ csv       │
# └────────────┴──────────┴───────────┴──────────┴───┴────────────┴────────────┴─────────┴───────────┘

# %%
pl.Config.set_fmt_table_cell_list_len(200) # Make the list column output longer
pl.Config.set_fmt_str_lengths(200) # Make string column output longer

(practice_quizzes_w_info :=
 practice_quizzes

.with_columns(path=pl.col('path').str.replace_all(r'\\', '/'))  # Replace \ with /
    .with_columns(path_split=pl.col('path').str.split('/'))
.with_columns(course_info = pl.col('path_split').list.get(3),
               file_name = pl.col('path_split').list.get(-1),
              )
  .with_columns(program = pl.col('course_info').str.slice(0,4),
                course_number = pl.col('course_info').str.slice(4, 3),
                section = pl.col('course_info').str.slice(7),
                quiz_type = pl.col('file_name').str.split(' ').list.get(0),
                )
 .drop(cs.starts_with('path', 'file') | cs.ends_with('info'))

)
# Out:
# shape: (1_611, 14)
# ┌──────────────┬──────────┬───────────┬──────────┬───┬─────────┬─────────────┬─────────┬───────────┐
# │ Org Defined  ┆ UserName ┆ FirstName ┆ LastName ┆ … ┆ program ┆ course_numb ┆ section ┆ quiz_type │
# │ ID           ┆ ---      ┆ ---       ┆ ---      ┆   ┆ ---     ┆ er          ┆ ---     ┆ ---       │
# │ ---          ┆ str      ┆ str       ┆ str      ┆   ┆ str     ┆ ---         ┆ str     ┆ str       │
# │ i64          ┆          ┆           ┆          ┆   ┆         ┆ str         ┆         ┆           │
# ╞══════════════╪══════════╪═══════════╪══════════╪═══╪═════════╪═════════════╪═════════╪═══════════╡
# │ 14460432     ┆ au9747cp ┆ Jericho   ┆ Greer    ┆ … ┆ dsci    ┆ 494         ┆ s7      ┆ Practice  │
# │ 14460432     ┆ au9747cp ┆ Jericho   ┆ Greer    ┆ … ┆ dsci    ┆ 494         ┆ s7      ┆ Practice  │
# │ 14460432     ┆ au9747cp ┆ Jericho   ┆ Greer    ┆ … ┆ dsci    ┆ 494         ┆ s7      ┆ Practice  │
# │ 14460432     ┆ au9747cp ┆ Jericho   ┆ Greer    ┆ … ┆ dsci    ┆ 494         ┆ s7      ┆ Practice  │
# │ 14460432     ┆ au9747cp ┆ Jericho   ┆ Greer    ┆ … ┆ dsci    ┆ 494         ┆ s7      ┆ Practice  │
# │ …            ┆ …        ┆ …         ┆ …        ┆ … ┆ …       ┆ …           ┆ …       ┆ …         │
# │ 18630821     ┆ ct6978kd ┆ Ekstrom   ┆ Czech    ┆ … ┆ stat    ┆ 491         ┆ s1      ┆ Practice  │
# │ 18630821     ┆ ct6978kd ┆ Ekstrom   ┆ Czech    ┆ … ┆ stat    ┆ 491         ┆ s1      ┆ Practice  │
# │ 18630821     ┆ ct6978kd ┆ Ekstrom   ┆ Czech    ┆ … ┆ stat    ┆ 491         ┆ s1      ┆ Practice  │
# │ 18630821     ┆ ct6978kd ┆ Ekstrom   ┆ Czech    ┆ … ┆ stat    ┆ 491         ┆ s1      ┆ Practice  │
# │ 18630821     ┆ ct6978kd ┆ Ekstrom   ┆ Czech    ┆ … ┆ stat    ┆ 491         ┆ s1      ┆ Practice  │
# └──────────────┴──────────┴───────────┴──────────┴───┴─────────┴─────────────┴─────────┴───────────┘
